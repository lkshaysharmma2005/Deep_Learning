# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Lakshay\Desktop\Deep Learning\Social_Network_Ads.csv")

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 215   60           108000          1
# 247   57           122000          1
# 8     25            33000          0
# 392   45            45000          1
# 147   41            30000          0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

X_scaled = pd.DataFrame(scaler.fit_transform(X)
                       ,columns=X.columns)

# %%
sns.scatterplot(data=X_scaled, x='Age', y='EstimatedSalary',hue=y)

plt.xlabel('Age')
plt.ylabel('EstimatedSalary')
plt.title('Age vs EstimatedSalary')
plt.show()

# %%
from sklearn.linear_model import Perceptron
perp = Perceptron()

# %%
perp.fit(X_scaled,y)
# Out:
# Perceptron()

# %%
perp.coef_
# Out:
# array([[1.33718381, 1.20395912]])

# %%
perp.intercept_
# Out:
# array([0.])

# %%
y_pred = perp.predict(X_scaled)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y,y_pred)
print(accuracy)
# Out:
# 0.805
